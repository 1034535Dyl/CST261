# %%
import week1_lab.ipynb
week1_lab.ipynb.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import week1_lab.ipynb
#       2 week1_lab.ipynb.main()
#
# ModuleNotFoundError: No module named 'week1_lab'

# %%
housing = strat_train_set.copy() 




housing.plot(kind="scatter", x="median_income", y="median_house_value", alpha=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 housing = strat_train_set.copy()
#       6 housing.plot(kind="scatter", x="median_income", y="median_house_value", alpha=0.1)
#
# NameError: name 'strat_train_set' is not defined
